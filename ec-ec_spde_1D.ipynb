# %%
# New notebook for data visualization of ec-ec spde in 1D
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
pyplot.style.use('seaborn')

# %%
# t_lambda & Tp (persistent time) characterize the solutions

# %%
x = pd.read_csv('x_axis.txt')
x
# Out:
#      x axis
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ..      ...
# 96       96
# 97       97
# 98       98
# 99       99
# 100     100
#
# [101 rows x 1 columns]

# %%
y_data = pd.read_csv("pde_data.txt",sep=" ",header=None)

# %%
y_data[0:50]
# Out:
#          0         1         2         3         4         5         6    \
# 0   0.050000  0.050000  0.050000  0.050000  0.050000  0.050000  0.050000
# 1   0.049869  0.051232  0.047465  0.051511  0.049941  0.049680  0.051336
# 2   0.049758  0.052416  0.044928  0.053047  0.049870  0.049372  0.052673
# 3   0.049646  0.053552  0.042432  0.054561  0.049829  0.049068  0.053955
# 4   0.049544  0.054618  0.039989  0.056100  0.049770  0.048785  0.055237
# 5   0.049418  0.055670  0.037542  0.057639  0.049751  0.048490  0.056516
# 6   0.049268  0.056665  0.035168  0.059137  0.049761  0.048225  0.057758
# 7   0.049126  0.057616  0.032785  0.060725  0.049731  0.047942  0.059016
# 8   0.049016  0.058482  0.030427  0.062335  0.049703  0.047657  0.060302
# 9   0.048910  0.059307  0.028081  0.063963  0.049664  0.047376  0.061568
# 10  0.048809  0.060082  0.025764  0.065617  0.049659  0.047063  0.062846
# 11  0.048697  0.060873  0.023453  0.067299  0.049658  0.046720  0.064136
# ...

# %%
y_data[5].plot(figsize=(15,7),legend=False)
plt.show()

# %%
# Solutions to stoch pde. Only noise and birth terms are included
plt.figure(figsize=(15,7))
plt.title("Time evolution of density")
y_data.iloc[0].plot(label='t = 10')
y_data.iloc[1].plot(label = 't = 20')
y_data.iloc[2].plot(label='t = 40')
y_data.iloc[3].plot(label='t = 40')

#y_data.iloc[40].plot(label='t = 80')
plt.legend()
plt.show()

# %%
ou = pd.read_csv("ou_process.txt",header=None)
ou
# Out:
#               0
# 0      13.23900
# 1      13.20680
# 2      13.80360
# 3      13.34860
# 4      13.10570
# ...         ...
# 9996   -5.42172
# 9997   -4.73825
# 9998   -4.53312
# 9999   -4.70708
# 10000  -4.46219
#
# [10001 rows x 1 columns]

# %%
ou.plot(figsize=(15,7))
plt.show()

# %%
spde = pd.read_csv("ec_ec_spde_2d.txt",sep=" ",header=None)
spde = spde.drop(columns=101,axis=1)

# %%
spde[707:808]
# Out:
#           0         1         2         3         4         5         6    \
# 707  0.002290  0.006674  0.005532  0.000140  0.009704  0.002955  0.009140
# 708  0.006914  0.005043  0.006327  0.005349  0.006294  0.006050  0.004620
# 709  0.002330  0.003361  0.007274  0.002640  0.005363  0.003233  0.002068
# 710  0.003247  0.010727  0.002398  0.011238  0.001954  0.006008  0.004546
# 711  0.005626  0.003955  0.003473  0.002210  0.010571  0.001427  0.005808
# ..        ...       ...       ...       ...       ...       ...       ...
# 803  0.005543  0.000533  0.007478 -0.000131  0.007706  0.003596  0.009291
# 804  0.000196  0.003785  0.007592  0.011082  0.003944  0.003428  0.004112
# 805  0.011965  0.009450  0.001957  0.006308  0.003208  0.001519  0.003550
# 806  0.001690  0.006279  0.004518  0.002298  0.007143  0.005093  0.004736
# 807  0.002290  0.006674  0.005532  0.000140  0.009704  0.002955  0.009140
#
#           7         8         9    ...       91        92        93   \
# ...

# %%
spde = spde.drop(columns=101,axis=1)

# %%
plt.figure()
plt.imshow(spde[101:202], cmap ="RdYlBu")

  
# Displaying a color bar to understand
# which color represents which range of data
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(spde[404:505], cmap ="RdYlBu")
plt.colorbar()
plt.show()
