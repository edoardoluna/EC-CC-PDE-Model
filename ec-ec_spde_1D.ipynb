# %%
# New notebook for data visualization of ec-ec spde in 1D
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
pyplot.style.use('seaborn')

# %%
# t_lambda & Tp (persistent time) characterize the solutions

# %%
x = pd.read_csv('x_axis.txt')
x
# Out:
#      x axis
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ..      ...
# 96       96
# 97       97
# 98       98
# 99       99
# 100     100
#
# [101 rows x 1 columns]

# %%
y_data = pd.read_csv("pde_data.txt",sep=" ",header=None)

# %%
y_data[0:10]
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.050000  0.050000  0.050000  0.050000  0.050000  0.050000  0.050000
# 1  0.050778  0.049705  0.050764  0.049134  0.049396  0.051632  0.049200
# 2  0.049735  0.048748  0.051111  0.049856  0.049141  0.052774  0.048315
# 3  0.048510  0.048480  0.051078  0.050633  0.048412  0.053014  0.048448
# 4  0.047895  0.049345  0.050420  0.051128  0.048848  0.052512  0.048722
# 5  0.048778  0.049964  0.050269  0.051427  0.049343  0.050923  0.049797
# 6  0.050166  0.049536  0.049402  0.051500  0.049296  0.051640  0.050758
# 7  0.050431  0.048592  0.049258  0.052109  0.049332  0.052034  0.050946
# 8  0.051312  0.047435  0.048631  0.053517  0.048875  0.053478  0.050313
# 9  0.052600  0.046337  0.048566  0.054459  0.048383  0.054101  0.050147
#
#         7         8         9    ...       92        93        94        95   \
# 0  0.050000  0.050000  0.050000  ...  0.050000  0.050000  0.050000  0.050000
# 1  0.050693  0.048717  0.049876  ...  0.050301  0.049404  0.049287  0.050289
# 2  0.050445  0.048176  0.049800  ...  0.049835  0.051106  0.048465  0.050574
# 3  0.049558  0.049036  0.050009  ...  0.049515  0.052625  0.048534  0.050325
# 4  0.048517  0.049447  0.050631  ...  0.049362  0.053398  0.047606  0.050986
# 5  0.047784  0.050682  0.050648  ...  0.049853  0.053366  0.047377  0.050621
# 6  0.047588  0.050659  0.050164  ...  0.050717  0.052652  0.046772  0.050829
# 7  0.047262  0.051240  0.049922  ...  0.050021  0.053627  0.046091  0.050715
# 8  0.046119  0.051978  0.048677  ...  0.050542  0.052540  0.047882  0.049726
# 9  0.045526  0.052588  0.047195  ...  0.051040  0.052865  0.047701  0.049750
#
#         96        97        98        99        100  101
# 0  0.050000  0.050000  0.050000  0.050000  0.050000  NaN
# 1  0.050458  0.050556  0.049267  0.050165  0.050778  NaN
# 2  0.050052  0.050915  0.049123  0.050235  0.049735  NaN
# 3  0.051351  0.049528  0.050129  0.049459  0.048510  NaN
# 4  0.052454  0.048190  0.051154  0.048761  0.047895  NaN
# 5  0.053755  0.047483  0.050152  0.048743  0.048778  NaN
# 6  0.054671  0.047051  0.050080  0.048637  0.050166  NaN
# 7  0.055635  0.046656  0.050310  0.047692  0.050431  NaN
# 8  0.055585  0.048122  0.049729  0.046314  0.051312  NaN
# 9  0.055132  0.048924  0.049057  0.045046  0.052600  NaN
#
# [10 rows x 102 columns]

# %%
y_data[list(np.arange(0,100))].plot(figsize=(15,7),legend=False)
plt.show()

# %%
# Solutions to stoch pde. Only noise and birth terms are included
plt.figure(figsize=(15,7))
plt.title("Time evolution of density")
y_data.iloc[0].plot(label='t = 10')
y_data.iloc[1].plot(label = 't = 20')
y_data.iloc[2].plot(label='t = 40')
y_data.iloc[3].plot(label='t = 40')

#y_data.iloc[40].plot(label='t = 80')
plt.legend()
plt.show()
